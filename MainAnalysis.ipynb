# %%
import pandas as pd
import numpy as np
import matplotlib

dataset = pd.read_excel("TOP-2000-2019.xlsx")
dataset
# Out:
#        NR.                                  TITEL  \
# 0        1                      Bohemian Rhapsody
# 1        2                       Hotel California
# 2        3                              Piano Man
# 3        4                         Roller Coaster
# 4        5                     Stairway To Heaven
# 5        6                                  Avond
# 6        7                                  Black
# 7        8                                Fix You
# 8        9                De Boer Dat Is De Keerl
# 9       10                     Wish You Were Here
# 10      11                                 Africa
# 11      12                          Child In Time
# 12      13                        Love Of My Life
# 13      14                          November Rain
# 14      15                   Nothing Else Matters
# 15      16                       Comfortably Numb
# 16      17                       Brothers In Arms
# 17      18                   The Sound Of Silence
# ...
